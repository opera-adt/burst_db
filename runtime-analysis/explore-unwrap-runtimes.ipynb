# %%
# If missing requirements: !pip install geopandas opera-utils pyarrow seaborn

# %%
import folium
import geopandas as gpd
import opera_utils
import pandas as pd

# %%
df = pd.read_parquet("disp-s1-unwrapping-runtimes.parquet")

# Convert to hours
runtime_cols = [
    "runtime_wrapped_phase",
    "runtime_stitching_bursts",
    "runtime_unwrap",
    "runtime_timeseries_inversion",
    "runtime_dolphin",
    "runtime_product",
    "runtime_disp_s1",
]
for col in runtime_cols:
    df[col] = (df[col] / 3600)
# Each ministack has 42 ifgs (except for first, which does 39)
# We run a default of n_parallel_jobs = 4 , factor back for the per-ifg number
# https://github.com/opera-adt/disp-s1/blob/d6e27cc06bbeda8ca1c3a0a7c98b351597e1d825/configs/algorithm_parameters_historical_20250401.yaml#L87
df["runtime_average_per_ifg_minutes"] = df["runtime_unwrap"] * 60 / 42 * 4


# Add the DISP-S1 Frame geometries
gdf = gpd.GeoDataFrame(
    pd.merge(
        df, opera_utils.get_frame_geodataframe(), left_on="frame_id", right_index=True
    )
)

# %%
gdf.iloc[0].T
# Out:
# frame_id                                                                        8882
# product_version                                                                  0.8
# generation_datetime                                              2024-11-14 23:56:30
# burst_id_count                                                                    27
# unwrap_method                                                                 snaphu
# max_memory_gb                                                                  34.18
# venue                                                                            pst
# logname                            OPERA_L3_DISP-S1_IW_F08882_v0.8_20241114T23563...
# runtime_wrapped_phase                                                            NaN
# runtime_stitching_bursts                                                         NaN
# runtime_unwrap                                                                   NaN
# runtime_snaphu                                                               63270.0
# runtime_spurt_tiling                                                            None
# runtime_spurt_merging                                                           None
# runtime_timeseries_inversion                                                0.103611
# runtime_dolphin                                                             7.434944
# runtime_product                                                             0.277933
# runtime_disp_s1                                                             7.712878
# spurt_number_of_tiles                                                           None
# spurt_total_num_points                                                           NaN
# spurt_num_points_per_tile                                                       None
# spurt_fraction_good                                                             None
# dolphin_version                                                               0.33.0
# disp_s1_version                                                                0.5.1
# log_path                           s3://opera-pst-rs-pop1/products/DISP_S1/OPERA_...
# runtime_average_per_ifg_minutes                                                  NaN
# is_land                                                                            1
# is_north_america                                                                True
# orbit_pass                                                                 ASCENDING
# geometry                           POLYGON ((-97.384771 30.022592, -94.830048 30....
# Name: 0, dtype: object

# %%
def explore(gdf, column, cmap="RdBu_r", vmax=240, vmin=30):  # noqa: D103
    m = folium.Map()

    # Create separate layers for each orbit pass type
    ascending = gdf[gdf["orbit_pass"] == "ASCENDING"].copy()
    descending = gdf[gdf["orbit_pass"] == "DESCENDING"].copy()
    # Sort by longitude (west to east) so eastern frames are on top
    # Use the centroid of each geometry to determine its longitude
    ascending.loc[:, "center_x"] = ascending.geometry.to_crs("EPSG:3857").centroid.x
    ascending = ascending.sort_values(by="center_x")
    descending.loc[:, "center_x"] = descending.geometry.to_crs("EPSG:3857").centroid.x
    descending = descending.sort_values(by="center_x")

    # Add layers with different colors
    ascending.explore(
        m=m,
        cmap=cmap,
        column=column,
        name="ASCENDING",
        vmin=vmin,
        vmax=vmax,
        style_kwds={"fillOpacity": 0.7},
    )

    descending.explore(
        m=m,
        cmap=cmap,
        column=column,
        name="DESCENDING",
        vmin=vmin,
        vmax=vmax,
        style_kwds={"fillOpacity": 0.7},
        legend=False,
    )

    # Add layer control
    folium.LayerControl().add_to(m)
    return m

def explore_column(  # noqa: D103
    gdf, col_name: str, agg_func="mean", cmap="RdYlBu_r", vmin_pct=.20, vmax_pct=0.95
) -> folium.Map:
    out = gdf.groupby("frame_id")[["geometry", "orbit_pass", col_name]].agg(
        {"geometry": "first", "orbit_pass": "first", col_name: agg_func}
    )
    out = out.set_geometry("geometry").set_crs(gdf.crs)
    vmin = out[col_name].quantile(vmin_pct)
    vmax = out[col_name].quantile(vmax_pct)
    return explore(out, col_name, cmap=cmap, vmax=vmax, vmin=vmin)

# %%
gdf_snaphu_ops = gdf[
    (gdf.unwrap_method == "snaphu") & (gdf.venue == "ops")
]

# %%
gdf_snaphu_ops.describe()
# Out:
#            frame_id  product_version         generation_datetime  \
# count  10607.000000          10607.0                       10607
# mean   23181.302630              1.0  2025-07-22 01:01:02.425379
# min      831.000000              1.0         2025-04-13 17:37:06
# 25%    12637.000000              1.0         2025-07-25 04:34:24
# 50%    22922.000000              1.0         2025-08-09 05:05:07
# 75%    34472.000000              1.0  2025-08-30 14:08:54.500000
# max    46543.000000              1.0         2025-09-04 09:04:09
# std    13209.056699              0.0                         NaN
#
#        burst_id_count  max_memory_gb  runtime_wrapped_phase  \
# count    10607.000000   10607.000000           10607.000000
# mean        21.566701      35.991921               0.297724
# min          1.000000      28.990000               0.070206
# 25%         18.000000      34.210000               0.265975
# 50%         27.000000      35.890000               0.311719
# 75%         27.000000      37.570000               0.345061
# max         27.000000      46.100000               0.461633
# std          7.941046       2.357158               0.064024
#
#        runtime_stitching_bursts  runtime_unwrap  runtime_timeseries_inversion  \
# count              10607.000000    10607.000000                  10607.000000
# mean                   0.130170        4.824759                      0.167255
# min                    0.032792        0.792825                      0.050000
# 25%                    0.110410        3.956140                      0.159167
# 50%                    0.145542        5.021364                      0.172778
# 75%                    0.156851        5.698139                      0.185833
# max                    0.179386       13.177086                      0.262222
# std                    0.034629        1.488676                      0.041679
#
#        runtime_dolphin  runtime_product  runtime_disp_s1  \
# count     10607.000000     10607.000000     10607.000000
# mean          5.941498         0.524575         6.466073
# min           1.004669         0.203106         1.218072
# 25%           4.816781         0.430706         5.258542
# 50%           6.332739         0.563858         6.911647
# 75%           7.052736         0.621174         7.649587
# max          14.580717         0.742028        15.157728
# std           1.780510         0.116437         1.872265
#
#        spurt_total_num_points  runtime_average_per_ifg_minutes  is_land
# count                     0.0                     10607.000000  10607.0
# mean                      NaN                        27.570051      1.0
# min                       NaN                         4.530429      1.0
# 25%                       NaN                        22.606516      1.0
# 50%                       NaN                        28.693508      1.0
# 75%                       NaN                        32.560794      1.0
# max                       NaN                        75.297635      1.0
# std                       NaN                         8.506719      0.0

# %%
explore_column(
    gdf_snaphu_ops,
    "runtime_disp_s1",
    vmax_pct=.95,
    agg_func='mean',
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69e77628900258eb5e0c74e7418fde97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69e77628900258eb5e0c74e7418fde97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_69e77628900258eb5e0c74e7418fde97 = L.map(
#                 &quot;map_69e77628900258eb5e0c74e7418fde97&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2922739fa8e1baae4eb453c1bcf07a1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e2922739fa8e1baae4eb453c1bcf07a1.addTo(map_69e77628900258eb5e0c74e7418fde97);
#
#
#         function geo_json_8f81c2daf67a1946a9cb78a049f84841_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;17&quot;: case &quot;20&quot;: case &quot;24&quot;: case &quot;31&quot;: case &quot;33&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;49&quot;: case &quot;61&quot;: case &quot;64&quot;: case &quot;74&quot;: case &quot;79&quot;: case &quot;81&quot;: case &quot;92&quot;: case &quot;95&quot;: case &quot;101&quot;: case &quot;102&quot;: case &quot;103&quot;: case &quot;104&quot;: case &quot;105&quot;: case &quot;106&quot;: case &quot;114&quot;: case &quot;117&quot;: case &quot;119&quot;: case &quot;128&quot;: case &quot;131&quot;: case &quot;135&quot;: case &quot;137&quot;: case &quot;139&quot;: case &quot;141&quot;: case &quot;142&quot;: case &quot;144&quot;: case &quot;157&quot;: case &quot;161&quot;: case &quot;162&quot;: case &quot;178&quot;: case &quot;191&quot;: case &quot;196&quot;: case &quot;202&quot;: case &quot;218&quot;: case &quot;236&quot;: case &quot;257&quot;: case &quot;258&quot;: case &quot;291&quot;: case &quot;294&quot;: case &quot;323&quot;: case &quot;339&quot;: case &quot;350&quot;: case &quot;380&quot;: case &quot;382&quot;: case &quot;406&quot;: case &quot;409&quot;: case &quot;414&quot;: case &quot;417&quot;: case &quot;426&quot;: case &quot;433&quot;: case &quot;436&quot;: case &quot;458&quot;: case &quot;459&quot;: case &quot;462&quot;: case &quot;468&quot;: case &quot;482&quot;: case &quot;486&quot;: case &quot;508&quot;: case &quot;512&quot;: case &quot;514&quot;: case &quot;523&quot;: case &quot;532&quot;: case &quot;536&quot;: case &quot;541&quot;: case &quot;546&quot;: case &quot;547&quot;: case &quot;550&quot;: case &quot;562&quot;: case &quot;574&quot;: case &quot;578&quot;: case &quot;581&quot;: case &quot;586&quot;: case &quot;589&quot;: case &quot;601&quot;: case &quot;608&quot;: case &quot;611&quot;: case &quot;612&quot;: case &quot;614&quot;: case &quot;615&quot;: case &quot;624&quot;: case &quot;627&quot;: case &quot;629&quot;: case &quot;637&quot;: case &quot;642&quot;: case &quot;646&quot;: case &quot;652&quot;: case &quot;654&quot;: case &quot;660&quot;: case &quot;663&quot;: case &quot;672&quot;: case &quot;673&quot;: case &quot;674&quot;: case &quot;676&quot;: case &quot;677&quot;: case &quot;680&quot;: case &quot;681&quot;: case &quot;682&quot;: case &quot;683&quot;: case &quot;684&quot;:
#                     return {&quot;color&quot;: &quot;#313695&quot;, &quot;fillColor&quot;: &quot;#313695&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     retu

# %%
explore_column(
    gdf_snaphu_ops,
    "runtime_wrapped_phase",
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c19c3d1fd77a015eeb3afe70070bcc5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c19c3d1fd77a015eeb3afe70070bcc5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c19c3d1fd77a015eeb3afe70070bcc5a = L.map(
#                 &quot;map_c19c3d1fd77a015eeb3afe70070bcc5a&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92d225e0a88d479f80899cb00605a418 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_92d225e0a88d479f80899cb00605a418.addTo(map_c19c3d1fd77a015eeb3afe70070bcc5a);
#
#
#         function geo_json_08a0efb1e52dfd7e5a56bde9d1303f84_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;3&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;31&quot;: case &quot;33&quot;: case &quot;34&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;49&quot;: case &quot;57&quot;: case &quot;61&quot;: case &quot;66&quot;: case &quot;103&quot;: case &quot;105&quot;: case &quot;117&quot;: case &quot;121&quot;: case &quot;122&quot;: case &quot;124&quot;: case &quot;127&quot;: case &quot;128&quot;: case &quot;129&quot;: case &quot;135&quot;: case &quot;140&quot;: case &quot;142&quot;: case &quot;157&quot;: case &quot;161&quot;: case &quot;163&quot;: case &quot;176&quot;: case &quot;186&quot;: case &quot;187&quot;: case &quot;190&quot;: case &quot;200&quot;: case &quot;202&quot;: case &quot;210&quot;: case &quot;211&quot;: case &quot;213&quot;: case &quot;214&quot;: case &quot;215&quot;: case &quot;218&quot;: case &quot;224&quot;: case &quot;227&quot;: case &quot;229&quot;: case &quot;238&quot;: case &quot;251&quot;: case &quot;252&quot;: case &quot;254&quot;: case &quot;258&quot;: case &quot;260&quot;: case &quot;271&quot;: case &quot;283&quot;: case &quot;287&quot;: case &quot;292&quot;: case &quot;294&quot;: case &quot;300&quot;: case &quot;304&quot;: case &quot;308&quot;: case &quot;323&quot;: case &quot;339&quot;: case &quot;359&quot;: case &quot;377&quot;: case &quot;380&quot;: case &quot;382&quot;: case &quot;402&quot;: case &quot;404&quot;: case &quot;409&quot;: case &quot;426&quot;: case &quot;433&quot;: case &quot;436&quot;: case &quot;459&quot;: case &quot;462&quot;: case &quot;468&quot;: case &quot;482&quot;: case &quot;483&quot;: case &quot;486&quot;: case &quot;487&quot;: case &quot;491&quot;: case &quot;508&quot;: case &quot;509&quot;: case &quot;512&quot;: case &quot;518&quot;: case &quot;532&quot;: case &quot;536&quot;: case &quot;538&quot;: case &quot;544&quot;: case &quot;547&quot;: case &quot;550&quot;: case &quot;561&quot;: case &quot;576&quot;: case &quot;581&quot;: case &quot;586&quot;: case &quot;589&quot;: case &quot;601&quot;: case &quot;608&quot;: case &quot;626&quot;: case &quot;627&quot;: case &quot;629&quot;: case &quot;638&quot;: case &quot;652&quot;: case &quot;653&quot;: case &quot;660&quot;: case &quot;663&quot;: case &quot;665&quot;: case &quot;666&quot;: case &quot;672&quot;: case &quot;675&quot;: case &quot;676&quot;: case &quot;679&quot;: case &quot;681&quot;: case &quot;682&quot;: case &quot;684&quot;:
#                     return {&quot;color&quot;: &quot;#313695&quot;, &quot;fillColor&quot;: &quot;#313695&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;52&q

# %%
explore_column(
    gdf_snaphu_ops,
    "runtime_unwrap",
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abc6a6ccb0b2fe5d4d737073c35d9d85 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abc6a6ccb0b2fe5d4d737073c35d9d85&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abc6a6ccb0b2fe5d4d737073c35d9d85 = L.map(
#                 &quot;map_abc6a6ccb0b2fe5d4d737073c35d9d85&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f3b033f508d679b61a6a7bb8f4e847e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8f3b033f508d679b61a6a7bb8f4e847e.addTo(map_abc6a6ccb0b2fe5d4d737073c35d9d85);
#
#
#         function geo_json_587cd1c3095d448fb848bb4500d479b6_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#3a51a2&quot;, &quot;fillColor&quot;: &quot;#3a51a2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;17&quot;: case &quot;20&quot;: case &quot;24&quot;: case &quot;31&quot;: case &quot;33&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;49&quot;: case &quot;61&quot;: case &quot;64&quot;: case &quot;74&quot;: case &quot;79&quot;: case &quot;81&quot;: case &quot;92&quot;: case &quot;95&quot;: case &quot;101&quot;: case &quot;102&quot;: case &quot;103&quot;: case &quot;104&quot;: case &quot;105&quot;: case &quot;106&quot;: case &quot;114&quot;: case &quot;117&quot;: case &quot;119&quot;: case &quot;128&quot;: case &quot;131&quot;: case &quot;135&quot;: case &quot;137&quot;: case &quot;139&quot;: case &quot;141&quot;: case &quot;142&quot;: case &quot;144&quot;: case &quot;147&quot;: case &quot;157&quot;: case &quot;161&quot;: case &quot;162&quot;: case &quot;178&quot;: case &quot;191&quot;: case &quot;196&quot;: case &quot;202&quot;: case &quot;218&quot;: case &quot;236&quot;: case &quot;257&quot;: case &quot;258&quot;: case &quot;291&quot;: case &quot;294&quot;: case &quot;323&quot;: case &quot;339&quot;: case &quot;350&quot;: case &quot;380&quot;: case &quot;382&quot;: case &quot;406&quot;: case &quot;409&quot;: case &quot;414&quot;: case &quot;417&quot;: case &quot;426&quot;: case &quot;433&quot;: case &quot;436&quot;: case &quot;458&quot;: case &quot;459&quot;: case &quot;462&quot;: case &quot;468&quot;: case &quot;482&quot;: case &quot;486&quot;: case &quot;508&quot;: case &quot;512&quot;: case &quot;514&quot;: case &quot;523&quot;: case &quot;532&quot;: case &quot;536&quot;: case &quot;541&quot;: case &quot;546&quot;: case &quot;547&quot;: case &quot;550&quot;: case &quot;562&quot;: case &quot;574&quot;: case &quot;578&quot;: case &quot;581&quot;: case &quot;586&quot;: case &quot;589&quot;: case &quot;601&quot;: case &quot;608&quot;: case &quot;611&quot;: case &quot;612&quot;: case &quot;615&quot;: case &quot;624&quot;: case &quot;627&quot;: case &quot;629&quot;: case &quot;637&quot;: case &quot;642&quot;: case &quot;646&quot;: case &quot;652&quot;: case &quot;660&quot;: case &quot;663&quot;: case &quot;672&quot;: case &quot;673&quot;: case &quot;674&quot;: case &quot;676&quot;: case &quot;677&quot;: case &quot;680&quot;: case &quot;681&quot;: case &quot;682&quot;: case &quot;683&quot;: case &quot;684&quot;:
#                     return {&quot;color&quot;: &quot;#313695&quot;, &quot;fillColor&qu

# %%
explore_column(
    gdf_snaphu_ops,
    "runtime_average_per_ifg_minutes",
    agg_func="median",
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20bcb9edb79fa544bfd474a917951fe3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20bcb9edb79fa544bfd474a917951fe3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20bcb9edb79fa544bfd474a917951fe3 = L.map(
#                 &quot;map_20bcb9edb79fa544bfd474a917951fe3&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4373913be3373ec4dc65bbba453741fc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4373913be3373ec4dc65bbba453741fc.addTo(map_20bcb9edb79fa544bfd474a917951fe3);
#
#
#         function geo_json_acf4bc19363ef3a401caf3eec3b27dde_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;33&quot;:
#                     return {&quot;color&quot;: &quot;#394fa1&quot;, &quot;fillColor&quot;: &quot;#394fa1&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;17&quot;: case &quot;20&quot;: case &quot;24&quot;: case &quot;31&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;49&quot;: case &quot;61&quot;: case &quot;74&quot;: case &quot;79&quot;: case &quot;81&quot;: case &quot;92&quot;: case &quot;95&quot;: case &quot;101&quot;: case &quot;102&quot;: case &quot;103&quot;: case &quot;104&quot;: case &quot;105&quot;: case &quot;106&quot;: case &quot;114&quot;: case &quot;117&quot;: case &quot;119&quot;: case &quot;122&quot;: case &quot;128&quot;: case &quot;131&quot;: case &quot;135&quot;: case &quot;137&quot;: case &quot;139&quot;: case &quot;141&quot;: case &quot;142&quot;: case &quot;144&quot;: case &quot;157&quot;: case &quot;161&quot;: case &quot;162&quot;: case &quot;186&quot;: case &quot;187&quot;: case &quot;191&quot;: case &quot;196&quot;: case &quot;202&quot;: case &quot;218&quot;: case &quot;236&quot;: case &quot;257&quot;: case &quot;258&quot;: case &quot;260&quot;: case &quot;291&quot;: case &quot;292&quot;: case &quot;294&quot;: case &quot;323&quot;: case &quot;339&quot;: case &quot;350&quot;: case &quot;377&quot;: case &quot;380&quot;: case &quot;382&quot;: case &quot;404&quot;: case &quot;406&quot;: case &quot;409&quot;: case &quot;414&quot;: case &quot;417&quot;: case &quot;426&quot;: case &quot;433&quot;: case &quot;436&quot;: case &quot;458&quot;: case &quot;459&quot;: case &quot;462&quot;: case &quot;468&quot;: case &quot;482&quot;: case &quot;486&quot;: case &quot;508&quot;: case &quot;512&quot;: case &quot;523&quot;: case &quot;532&quot;: case &quot;536&quot;: case &quot;541&quot;: case &quot;546&quot;: case &quot;547&quot;: case &quot;550&quot;: case &quot;562&quot;: case &quot;574&quot;: case &quot;578&quot;: case &quot;581&quot;: case &quot;586&quot;: case &quot;589&quot;: case &quot;601&quot;: case &quot;608&quot;: case &quot;611&quot;: case &quot;612&quot;: case &quot;615&quot;: case &quot;624&quot;: case &quot;627&quot;: case &quot;629&quot;: case &quot;637&quot;: case &quot;642&quot;: case &quot;646&quot;: case &quot;652&quot;: case &quot;660&quot;: case &quot;663&quot;: case &quot;668&quot;: case &quot;672&quot;: case &quot;673&quot;: case &quot;674&quot;: case &quot;676&quot;: case &quot;677&quot;: case &quot;680&quot;: case &quot;681&quot;: case &quot;683&quot;: case &quot;684&quot;:
