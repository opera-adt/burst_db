# %%
# If missing requirements: !pip install geopandas opera-utils pyarrow seaborn

# %%
import geopandas as gpd
import opera_utils
import pandas as pd

# %%
df = pd.read_parquet("disp-s1-unwrapping-runtimes.parquet")

# Convert to hours
runtime_cols = [
    "runtime_wrapped_phase",
    "runtime_stitching_bursts",
    "runtime_unwrap",
    "runtime_timeseries_inversion",
    "runtime_dolphin",
    "runtime_product",
    "runtime_disp_s1",
]
for col in runtime_cols:
    df[col] = (df[col] / 3600)
# Each ministack has 42 ifgs (except for first, which does 39)
# We run a default of n_parallel_jobs = 4 , factor back for the per-ifg number
# https://github.com/opera-adt/disp-s1/blob/d6e27cc06bbeda8ca1c3a0a7c98b351597e1d825/configs/algorithm_parameters_historical_20250401.yaml#L87
df["runtime_average_per_ifg_minutes"] = df["runtime_unwrap"] * 60 / 42 * 4


# Add the DISP-S1 Frame geometries
gdf = gpd.GeoDataFrame(
    pd.merge(
        df, opera_utils.get_frame_geodataframe(), left_on="frame_id", right_index=True
    )
)

# %%
gdf.head(2)
# Out:
#    frame_id  product_version generation_datetime  burst_id_count  \
# 0      8882              0.8 2024-11-14 23:56:30              27
# 1      8622              0.8 2024-11-14 23:59:18              25
#
#   unwrap_method  max_memory_gb venue  \
# 0        snaphu          34.18   pst
# 1        snaphu          35.11   pst
#
#                                              logname  runtime_wrapped_phase  \
# 0  OPERA_L3_DISP-S1_IW_F08882_v0.8_20241114T23563...                    NaN
# 1  OPERA_L3_DISP-S1_IW_F08622_v0.8_20241114T23591...                    NaN
#
#    runtime_stitching_bursts  ...  spurt_num_points_per_tile  \
# 0                       NaN  ...                       None
# 1                       NaN  ...                       None
#
#   spurt_fraction_good dolphin_version disp_s1_version  \
# 0                None          0.33.0           0.5.1
# 1                None          0.33.0           0.5.1
#
#                                             log_path  \
# 0  s3://opera-pst-rs-pop1/products/DISP_S1/OPERA_...
# 1  s3://opera-pst-rs-pop1/products/DISP_S1/OPERA_...
#
#    runtime_average_per_ifg_minutes  is_land  is_north_america orbit_pass  \
# 0                              NaN        1              True  ASCENDING
# 1                              NaN        1              True  ASCENDING
#
#                                             geometry
# 0  POLYGON ((-97.38477 30.02259, -94.83005 30.547...
# 1  POLYGON ((-75.36963 41.30259, -72.41804 41.813...
#
# [2 rows x 30 columns]

# %%
def explore_column(  # noqa: D103
    gdf, col_name: str, agg_func="mean", cmap="RdYlBu_r", vmin_pct=.20, vmax_pct=0.95
) -> gpd.GeoDataFrame:
    out = gdf.groupby("frame_id")[["geometry", col_name]].agg(
        {"geometry": "first", col_name: agg_func}
    )

    out = out.set_geometry("geometry").set_crs(gdf.crs)
    vmin = out[col_name].quantile(vmin_pct)
    vmax = out[col_name].quantile(vmax_pct)
    return out.explore(column=col_name, cmap=cmap, vmin=vmin, vmax=vmax)

# %%
gdf_snaphu_ops = gdf[
    (gdf.unwrap_method == "snaphu") & (gdf.venue == "ops")
]

# %%
gdf_snaphu_ops.describe()
# Out:
#            frame_id  product_version         generation_datetime  \
# count   5645.000000           5645.0                        5645
# mean   23123.022675              1.0  2025-06-17 01:48:24.282373
# min      831.000000              1.0         2025-04-13 17:37:06
# 25%    12639.000000              1.0         2025-04-18 11:15:34
# 50%    22668.000000              1.0         2025-07-25 11:39:29
# 75%    34223.000000              1.0         2025-07-28 09:15:05
# max    46293.000000              1.0         2025-08-11 12:03:17
# std    13197.558690              0.0                         NaN
#
#        burst_id_count  max_memory_gb  runtime_wrapped_phase  \
# count     5645.000000    5645.000000            5645.000000
# mean        21.344730      36.126062               0.304936
# min          1.000000      29.570000               0.090339
# 25%         16.000000      34.390000               0.274822
# 50%         27.000000      36.060000               0.318997
# 75%         27.000000      37.600000               0.346792
# max         27.000000      45.490000               0.455994
# std          7.978345       2.205721               0.059655
#
#        runtime_stitching_bursts  runtime_unwrap  runtime_timeseries_inversion  \
# count               5645.000000     5645.000000                   5645.000000
# mean                   0.131395        4.937895                      0.186661
# min                    0.040833        0.906667                      0.078056
# 25%                    0.112311        4.439414                      0.170278
# 50%                    0.145775        5.053306                      0.181111
# 75%                    0.156006        5.676122                      0.210278
# max                    0.177694       10.575800                      0.262222
# std                    0.033708        1.323804                      0.027651
#
#        runtime_dolphin  runtime_product  runtime_disp_s1  \
# count      5645.000000      5645.000000      5645.000000
# mean          6.100450         0.556183         6.656634
# min           1.219119         0.245281         1.488789
# 25%           5.500436         0.475900         5.995500
# 50%           6.382514         0.598867         7.000714
# 75%           7.032439         0.638725         7.657431
# max          12.006244         0.742028        12.685083
# std           1.597705         0.110720         1.687554
#
#        spurt_total_num_points  runtime_average_per_ifg_minutes  is_land
# count                     0.0                      5645.000000   5645.0
# mean                      NaN                        28.216541      1.0
# min                       NaN                         5.180952      1.0
# 25%                       NaN                        25.368079      1.0
# 50%                       NaN                        28.876032      1.0
# 75%                       NaN                        32.434984      1.0
# max                       NaN                        60.433143      1.0
# std                       NaN                         7.564593      0.0

# %%
explore_column(
    gdf_snaphu_ops,
    "runtime_disp_s1",
    vmax_pct=.95,
    agg_func='mean',
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a065643305555c8c9784e10bdab86a77 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a065643305555c8c9784e10bdab86a77&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a065643305555c8c9784e10bdab86a77 = L.map(
#                 &quot;map_a065643305555c8c9784e10bdab86a77&quot;,
#                 {
#                     center: [13.873765999999998, -12.573340000000002],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_a065643305555c8c9784e10bdab86a77);
#
#
#
#
#
#             var tile_layer_7b5b00fdb2f3a772baf581c95733e47b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7b5b00fdb2f3a772baf581c95733e47b.addTo(map_a065643305555c8c9784e10bdab86a77);
#
#
#             map_a065643305555c8c9784e10bdab86a77.fitBounds(
#                 [[-15.289224, -172.388991], [43.036756, 147.242311]],
#                 {}
#             );
#
#
#         function geo_json_c544a878b119dda0849dc67c2e949541_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#5c90c2&quot;, &quot;fillColor&quot;: &quot;#5c90c2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;392&quot;:
#                     return {&quot;color&quot;: &quot;#dc3b2c&quot;, &quot;fillColor&quot;: &quot;#dc3b2c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;126&quot;: case &quot;290&quot;: case &quot;316&quot;: case &quot;319&quot;:
#                     return {&quot;color&quot;: &quot;#f7814c&quot;, &quot;fillColor&quot;: &quot;#f7814c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;41&quot;: case &quot;184&quot;: case &quot;278&quot;: case &quot;341&quot;:
#                     return {&quot;color&quot;: &quot;#fee294&quot;, &quot;fillColor&quot;: &quot;#fee294&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;22&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;47&quot;: case &quot;57&quot;: case &quot;58&quot;: case &quot;59&quot;: case &quot;65&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;77&quot;: case &quot;78&quot;: case &quot;80&quot;: case &quot;85&quot;: case &quot;93&quot;: case &quot;97&quot;: case &quot;99&quot;: case &quot;100&quot;: case &quot;110&quot;: case &quot;112&quot;: case &quot;113&quot;: case &quot;124&quot;: case &quot;138&quot;: case &quot;139&quot;: case &quot;143&quot;: case &quot;150&quot;: case &quot;151&quot;: case &quot;152&quot;: case &quot;154&quot;: case &quot;155&quot;: case &quot;163&quot;: case &quot;172&quot;: case &quot;173&quot;: case &quot;175&quot;: case &quot;180&quot;: case &quot;181&quot;: case &quot;182&quot;: case &quot;187&quot;: case &quot;204&quot;: case &quot;205&quot;: case &quot;206&quot;: case &quot;210&quot;: case &quot;224&quot;: case &quot;225&quot;: case &quot;226&quot;: case &quot;233&quot;: case &quot;234&quot;: case &quot;235&quot;: case &quot;244&quot;: case &quot;248&quot;: case &quot;259&quot;: case &quot;260&quot;: case &quot;261&quot;: case &quot;265&quot;: case &quot;270&quot;: case &quot;271&quot;: case &quot;285&quot;: case &quot;286&quot;: case &quot;297&quot;: case &quot;299&quot;: case &quot;300&quot;: case &quot;301&quot;: case &quot;311&quot;: case &quot;312&quot;: case &quot;314&quot;: case &quot;323&quot;: case &quot;324&quot;: case &quot;331&quot;: case &quot;338&quot;: case &quot;342&quot;: case &quot;347&quot;: case &quot;360&quot;: case &quot;361&quot;: case &quot;362&quot;: case &quot;363&quot;: case &quot;367&quot;: case &quot;370&quot;: case &quot;371&quot;: case &quot;372&quot;: case &quot;377&quot;: case &quot;396&quot;: case &quot;406&quot;: case &quot;407&quot;: case &quot;413&quot;: case &quot;436&quot;:
#                     return {&quot;color&quot;: &quot;#313695&quot;, &quot;fillColor&quot;: &quot;#313695&quot;, &quot;fillOpacity&quot;: 0.5

# %%
explore_column(
    gdf_snaphu_ops,
    "runtime_wrapped_phase",
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b22d7ff793e4e5ff110cbefc63b8302 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b22d7ff793e4e5ff110cbefc63b8302&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b22d7ff793e4e5ff110cbefc63b8302 = L.map(
#                 &quot;map_0b22d7ff793e4e5ff110cbefc63b8302&quot;,
#                 {
#                     center: [13.873765999999998, -12.573340000000002],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_0b22d7ff793e4e5ff110cbefc63b8302);
#
#
#
#
#
#             var tile_layer_b232261dda64c370197b7a888bcbffeb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b232261dda64c370197b7a888bcbffeb.addTo(map_0b22d7ff793e4e5ff110cbefc63b8302);
#
#
#             map_0b22d7ff793e4e5ff110cbefc63b8302.fitBounds(
#                 [[-15.289224, -172.388991], [43.036756, 147.242311]],
#                 {}
#             );
#
#
#         function geo_json_4f850cd1f411d922361a39f8042671bd_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#4b7db8&quot;, &quot;fillColor&quot;: &quot;#4b7db8&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#dd3d2d&quot;, &quot;fillColor&quot;: &quot;#dd3d2d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;374&quot;:
#                     return {&quot;color&quot;: &quot;#a70226&quot;, &quot;fillColor&quot;: &quot;#a70226&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;421&quot;:
#                     return {&quot;color&quot;: &quot;#f16640&quot;, &quot;fillColor&quot;: &quot;#f16640&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;194&quot;:
#                     return {&quot;color&quot;: &quot;#fff1aa&quot;, &quot;fillColor&quot;: &quot;#fff1aa&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;153&quot;: case &quot;345&quot;:
#                     return {&quot;color&quot;: &quot;#e54e35&quot;, &quot;fillColor&quot;: &quot;#e54e35&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;186&quot;:
#                     return {&quot;color&quot;: &quot;#c62027&quot;, &quot;fillColor&quot;: &quot;#c62027&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;63&quot;:
#                     return {&quot;color&quot;: &quot;#d83128&quot;, &quot;fillColor&quot;: &quot;#d83128&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;: case &quot;122&quot;:
#                     return {&quot;color&quot;: &quot;#bb1526&quot;, &quot;fillColor&quot;: &quot;#bb1526&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#e24731&quot;, &quot;fillColor&quot;: &quot;#e24731&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;86&quot;: case &quot;179&quot;: case &quot;334&quot;: case &quot;398&quot;:
#                     return {&quot;color&quot;: &quot;#fdb769&quot;, &quot;fillColor&quot;: &quot;#fdb769&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;88&quot;: case &quot;158&quot;:
#                     return {&quot;color&quot;: &quot;#fdb567&quot;, &quot;fillColor&quot;: &quot;#fdb567&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;: case &quot;167&quot;: case &quot;288&quot;: case &quot;401&quot;:
#                     return {&quot;color&quot;: &quot;#fdc374&quot;, &quot;fillColor&quot;: &quot;#fdc374&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;:
#                     return {&q

# %%
explore_column(
    gdf_snaphu_ops,
    "runtime_unwrap",
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e92c0fb92683bdffeba7640c813bd8af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e92c0fb92683bdffeba7640c813bd8af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e92c0fb92683bdffeba7640c813bd8af = L.map(
#                 &quot;map_e92c0fb92683bdffeba7640c813bd8af&quot;,
#                 {
#                     center: [13.873765999999998, -12.573340000000002],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_e92c0fb92683bdffeba7640c813bd8af);
#
#
#
#
#
#             var tile_layer_1e790b74af783a1d24f8a6eb360f75c2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1e790b74af783a1d24f8a6eb360f75c2.addTo(map_e92c0fb92683bdffeba7640c813bd8af);
#
#
#             map_e92c0fb92683bdffeba7640c813bd8af.fitBounds(
#                 [[-15.289224, -172.388991], [43.036756, 147.242311]],
#                 {}
#             );
#
#
#         function geo_json_82de520529a3692e32520b7d8a8502e1_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;147&quot;: case &quot;162&quot;:
#                     return {&quot;color&quot;: &quot;#72abd0&quot;, &quot;fillColor&quot;: &quot;#72abd0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#e24731&quot;, &quot;fillColor&quot;: &quot;#e24731&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;191&quot;:
#                     return {&quot;color&quot;: &quot;#fca55d&quot;, &quot;fillColor&quot;: &quot;#fca55d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;169&quot;:
#                     return {&quot;color&quot;: &quot;#fffab7&quot;, &quot;fillColor&quot;: &quot;#fffab7&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;22&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;47&quot;: case &quot;57&quot;: case &quot;58&quot;: case &quot;65&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;77&quot;: case &quot;78&quot;: case &quot;80&quot;: case &quot;85&quot;: case &quot;93&quot;: case &quot;94&quot;: case &quot;97&quot;: case &quot;99&quot;: case &quot;100&quot;: case &quot;109&quot;: case &quot;110&quot;: case &quot;112&quot;: case &quot;113&quot;: case &quot;124&quot;: case &quot;138&quot;: case &quot;139&quot;: case &quot;143&quot;: case &quot;150&quot;: case &quot;151&quot;: case &quot;152&quot;: case &quot;154&quot;: case &quot;155&quot;: case &quot;163&quot;: case &quot;172&quot;: case &quot;173&quot;: case &quot;175&quot;: case &quot;180&quot;: case &quot;181&quot;: case &quot;182&quot;: case &quot;187&quot;: case &quot;204&quot;: case &quot;206&quot;: case &quot;210&quot;: case &quot;224&quot;: case &quot;225&quot;: case &quot;226&quot;: case &quot;233&quot;: case &quot;234&quot;: case &quot;235&quot;: case &quot;244&quot;: case &quot;248&quot;: case &quot;259&quot;: case &quot;260&quot;: case &quot;265&quot;: case &quot;270&quot;: case &quot;271&quot;: case &quot;273&quot;: case &quot;285&quot;: case &quot;286&quot;: case &quot;296&quot;: case &quot;297&quot;: case &quot;299&quot;: case &quot;300&quot;: case &quot;301&quot;: case &quot;311&quot;: case &quot;312&quot;: case &quot;314&quot;: case &quot;323&quot;: case &quot;324&quot;: case &quot;331&quot;: case &quot;338&quot;: case &quot;347&quot;: case &quot;360&quot;: case &quot;361&quot;: case &quot;362&quot;: case &quot;363&quot;: case &quot;367&quot;: case &quot;369&quot;: case &quot;370&quot;: case &quot;371&quot;: case &quot;372&quot;: case &quot;377&quot;: case &quot;396&quot;: case &quot;406&quot;: case &quot;407&quot;: case &quot;413&quot;: case &quot;436&quot;:
#                     return {&quot;color&quot;: &quot;#313695&quot;, &quot;fillColor&quot;: &quot;#313695&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;222&quot;: cas

# %%
explore_column(
    gdf_snaphu_ops,
    "runtime_average_per_ifg_minutes",
    agg_func="median",
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_235cc28c537e5c34703c482ddefe4897 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_235cc28c537e5c34703c482ddefe4897&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_235cc28c537e5c34703c482ddefe4897 = L.map(
#                 &quot;map_235cc28c537e5c34703c482ddefe4897&quot;,
#                 {
#                     center: [13.873765999999998, -12.573340000000002],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_235cc28c537e5c34703c482ddefe4897);
#
#
#
#
#
#             var tile_layer_57ac79880cb042f52290ca419a7181b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_57ac79880cb042f52290ca419a7181b8.addTo(map_235cc28c537e5c34703c482ddefe4897);
#
#
#             map_235cc28c537e5c34703c482ddefe4897.fitBounds(
#                 [[-15.289224, -172.388991], [43.036756, 147.242311]],
#                 {}
#             );
#
#
#         function geo_json_d7eabfa4028320ae3230b739ffa80fac_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;162&quot;: case &quot;249&quot;:
#                     return {&quot;color&quot;: &quot;#78b0d3&quot;, &quot;fillColor&quot;: &quot;#78b0d3&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#da362a&quot;, &quot;fillColor&quot;: &quot;#da362a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#fdc576&quot;, &quot;fillColor&quot;: &quot;#fdc576&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;68&quot;: case &quot;132&quot;:
#                     return {&quot;color&quot;: &quot;#fffab7&quot;, &quot;fillColor&quot;: &quot;#fffab7&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;22&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;47&quot;: case &quot;57&quot;: case &quot;58&quot;: case &quot;65&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;77&quot;: case &quot;78&quot;: case &quot;80&quot;: case &quot;85&quot;: case &quot;93&quot;: case &quot;94&quot;: case &quot;97&quot;: case &quot;99&quot;: case &quot;100&quot;: case &quot;109&quot;: case &quot;110&quot;: case &quot;112&quot;: case &quot;113&quot;: case &quot;124&quot;: case &quot;138&quot;: case &quot;139&quot;: case &quot;143&quot;: case &quot;150&quot;: case &quot;151&quot;: case &quot;152&quot;: case &quot;154&quot;: case &quot;155&quot;: case &quot;163&quot;: case &quot;172&quot;: case &quot;173&quot;: case &quot;175&quot;: case &quot;180&quot;: case &quot;181&quot;: case &quot;182&quot;: case &quot;187&quot;: case &quot;204&quot;: case &quot;206&quot;: case &quot;210&quot;: case &quot;224&quot;: case &quot;225&quot;: case &quot;226&quot;: case &quot;233&quot;: case &quot;234&quot;: case &quot;235&quot;: case &quot;244&quot;: case &quot;248&quot;: case &quot;259&quot;: case &quot;260&quot;: case &quot;265&quot;: case &quot;270&quot;: case &quot;271&quot;: case &quot;273&quot;: case &quot;285&quot;: case &quot;286&quot;: case &quot;296&quot;: case &quot;297&quot;: case &quot;300&quot;: case &quot;301&quot;: case &quot;311&quot;: case &quot;312&quot;: case &quot;314&quot;: case &quot;323&quot;: case &quot;324&quot;: case &quot;331&quot;: case &quot;338&quot;: case &quot;347&quot;: case &quot;360&quot;: case &quot;361&quot;: case &quot;362&quot;: case &quot;363&quot;: case &quot;367&quot;: case &quot;369&quot;: case &quot;370&quot;: case &quot;371&quot;: case &quot;372&quot;: case &quot;377&quot;: case &quot;396&quot;: case &quot;406&quot;: case &quot;407&quot;: case &quot;413&quot;: case &quot;436&quot;:
#                     return {&quot;color&quot;: &quot;#313695&quot;, &quot;fillColor&quot;: &quot;#313695&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;222&quot;: case &
